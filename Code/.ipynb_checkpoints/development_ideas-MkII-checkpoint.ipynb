# %% [markdown]
# # Network classifier notebook
# For implementing new ideas!
#
# First run the main thing

# %%
import numpy as np

# Basic script to run network state classfication

from loadSeizureData  import LoadSeizureData
from classifierTester import ClassifierTester
from basicFeatures    import BasicFeatures
from randomForestClassifier import RandomForest
from freqfeatures     import FreqFeatures

dirpath = '/Users/Jonathan/Documents/PhD /Seizure_related/Network_states/VMData/Classified'


dataobj = LoadSeizureData(dirpath)
dataobj.load_data()

basicStatsExtractor = BasicFeatures()
#freqextractor = FreqFeatures()
dataobj.extract_feature_array([basicStatsExtractor])
#dataobj.extract_feature_array([freqextractor])

rf = RandomForest(no_trees = 100)
results = []
runs = 10
for i in range(runs):
    classtester = ClassifierTester(dataobj.features,np.ravel(dataobj.label_colarray), training_test_split = 80)
    (score, predictedlabelsprobs, reallabels) = classtester.test_classifier(rf)
    results.append(score)

print 'training a random forest classifier!'
print results
print np.mean(results), ' mean score'
# Out:
# here2
# training a random forest classifier!
# [85.245901639344254, 77.049180327868854, 81.967213114754102, 85.245901639344254, 81.967213114754102, 81.967213114754102, 81.967213114754102, 73.770491803278688, 77.049180327868854, 80.327868852459019]
# 80.6557377049  mean score

# %% [markdown]
# ## Understanding the feature dataset
# 1. Scatter plot matrix
# 2. Radviz
# 3. pca projection

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
#import matplotlib
#matplotlib.style.use('ggplot')

#df = pd.DataFrame(dataobj.features, columns = ['kurtosis','skew','coastline'])
df = pd.DataFrame(dataobj.features, columns = ['kurtosis','skew','variation','coastline'])
#df = pd.DataFrame(dataobj.features)
print dataobj.features.shape
df.head(3)
# Out:
# (301, 4)
#    kurtosis      skew  variation  coastline
# 0  2.801378 -2.824507   0.054283  -0.998260
# 1 -0.840246  0.709462   0.005613   0.517446
# 2 -0.057909  0.984643  -0.051536  -0.908706

# %% [markdown]
# #Scatter Plot Matrix

# %%
import seaborn as sns
#sns.despine(offset=10, trim=True); # try using this ;ater

# %%
sns.set(style="white")
#sns.set()

dd
#sns.pairplot(df, size=2.5)
sns.set_context("talk", font_scale=1.00)
pg = sns.pairplot(df, vars=['kurtosis','skew','variation','coastline'],
                  hue="Network States", size = 2)

#f = sns.pairplot(df, vars=['kurtosis','skew','variation','coastline'], hue="labels", palette="Set2", diag_kind="kde", size = 2.5)
#g.map(plt.scatter)
#g = sns.PairGrid(df, vars=['kurtosis','skew','variation','coastline'], hue="labels", size = 4)

#plt.savefig('scatter_matrix.png')
#pg.add_legend(size = 15)
#plt.legend()
for legend in pg.fig.legends:
    plt.setp(legend.get_title(),fontsize=15)

# %% [markdown]
# #Radviz

# %%
# %matplotlib inline 
from pandas.tools.plotting import radviz

cmap =  sns.color_palette()
plt.figure(figsize = (10,7))
ax = plt.subplot(111)
radviz(df,'Network States', ax = ax, color = cmap, edgecolor = 'white')
ax.legend(frameon = False)
ax.axis('off')
#legend = ax.legend(title = 'Network States')
plt.setp(legend.get_title(),fontsize=15)

#ax.legend( loc='center left', bbox_to_anchor=(0, 1),fontsize='medium', fancybox=True, ncol=3 )
ax.set_xlim((-1.1, 1.1))
ax.set_ylim((-1.1, 1.1))#, emit=True, auto=False )
#ax.set_title( 'Radviz visualisation of feature matrix', loc='Center' )
for text in ax.texts:
    text.set_size(15)
#mpld3.enable_notebook()
#plt.savefig('radviz.png')

# %% [markdown]
# # Plotting interactively
# pause on the PCA for the moment, the radviz seems pretty damn good. focus on being able to verify the 10 secs are actually what we think they are.

# %%
# %matplotlib qt
from matplotlib import pyplot as plt

class LineBuilder:
    def __init__(self, line):
        self.line = line
        self.xs = list(line.get_xdata())
        self.ys = list(line.get_ydata())
        self.cid = line.figure.canvas.mpl_connect('button_press_event', self)

    def __call__(self, event):
        print 'click', event
        if event.inaxes!=self.line.axes: return
        self.xs.append(event.xdata)
        self.ys.append(event.ydata)
        self.line.set_data(self.xs, self.ys)
        self.line.figure.canvas.draw()

fig = plt.figure()
ax = fig.add_subplot(111)
ax.set_title('click to build line segments')
line, = ax.plot([0], [0])  # empty line
linebuilder = LineBuilder(line)

plt.show()
# Out:
# click MPL MouseEvent: xy=(235,324) xydata=(-0.0225,0.02625) button=1 dblclick=False inaxes=Axes(0.125,0.1;0.775x0.8)
# click MPL MouseEvent: xy=(189,299) xydata=(-0.0336290322581,0.0184375) button=1 dblclick=False inaxes=Axes(0.125,0.1;0.775x0.8)
# click MPL MouseEvent: xy=(414,299) xydata=(0.0208064516129,0.0184375) button=1 dblclick=False inaxes=Axes(0.125,0.1;0.775x0.8)
# click MPL MouseEvent: xy=(427,260) xydata=(0.0239516129032,0.00625) button=1 dblclick=False inaxes=Axes(0.125,0.1;0.775x0.8)
# click MPL MouseEvent: xy=(327,173) xydata=(-0.000241935483871,-0.0209375) button=1 dblclick=False inaxes=Axes(0.125,0.1;0.775x0.8)
# click MPL MouseEvent: xy=(223,164) xydata=(-0.0254032258065,-0.02375) button=1 dblclick=False inaxes=Axes(0.125,0.1;0.775x0.8)
# click MPL MouseEvent: xy=(203,232) xydata=(-0.0302419354839,-0.0025) button=1 dblclick=False inaxes=Axes(0.125,0.1;0.775x0.8)
# click MPL MouseEvent: xy=(220,324) xydata=(-0.0261290322581,0.02625) button=1 dblclick=False inaxes=Axes(0.125,0.1;0.775x0.8)
# click MPL MouseEvent: xy=(350,361) xydata=(0.00532258064516,0.0378125) button=1 dblclick=False inaxes=Axes(0.125,0.1;0.775x0.8)
# click MPL MouseEvent: xy=(427,365) xydata=(0.0239516129032,0.0390625) button=1 dblclick=False inaxes=Axes(0.125,0.1;0.775x0.8)
# click MPL MouseEvent: xy=(516,274) xydata=(0.0454838709677,0.010625) button=1 dblclick=False inaxes=Axes(0.125,0.1;0.775x0.8)
# click MPL MouseEvent: xy=(481,174) xydata=(0.0370161290323,-0.020625) button=1 dblclick=False inaxes=Axes(0.125,0.1;0.775x0.8)
# click MPL MouseEvent: xy=(362,139) xydata=(0.00822580645161,-0.0315625) button=1 dblclick=False inaxes=Axes(0.125,0.1;0.775x0.8)
# click MPL MouseEvent: xy=(259,138) xydata=(-0.0166935483871,-0.031875) button=1 dblclick=False inaxes=Axes(0.125,0.1;0.775x0.8)
# click MPL MouseEvent: xy=(162,158) xydata=(-0.0401612903226,-0.025625) button=1 dblclick=False inaxes=Axes(0.125,0.1;0.775x0.8)
# click MPL MouseEvent: xy=(207,272) xydata=(-0.0292741935484,0.01) button=1 dblclick=False inaxes=Axes(0.125,0.1;0.775x0.8)
# click

# %% [markdown]
# #try mpld3?

# %%
# %matplotlib inline
import mpld3

# %%
mpld3.enable_notebook()

# %%
from mpld3 import plugins

fig, ax = plt.subplots(subplot_kw=dict(axisbg='#EEEEEE'))
ax.grid(color='white', linestyle='solid')

N = 50
scatter = ax.scatter(np.random.normal(size=N),
                     np.random.normal(size=N),
                     c=np.random.random(size=N),
                     s = 1000 * np.random.random(size=N),
                     alpha=0.3,
                     cmap=plt.cm.jet)

ax.set_title("D3 Scatter Plot (with tooltips!)", size=20)

labels = ['point {0}'.format(i + 1) for i in range(N)]
fig.plugins = [plugins.PointLabelTooltip(scatter, labels)]

# %%
import seaborn as sns
sns.set()

df = sns.load_dataset("iris")

sns.pairplot(df, hue="species", size=2.5)

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
import lightning

# %%
import networkx as nx
from numpy import random

G = nx.random_regular_graph(3,100)
mat = nx.adjacency_matrix(G).todense()
l = (random.rand(100)*5).astype('int')

lgn.force(mat, label=l)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-5899ada8ac48> in <module>()
#       6 l = (random.rand(100)*5).astype('int')
#       7
# ----> 8 lgn.force(mat, label=l)
#
# NameError: name 'lgn' is not defined

# %%
def radviz2(frame, class_column, ax=None, color=None, colormap=None, **kwds):
    """RadViz - a multivariate data visualization algorithm
    Parameters:
    -----------
    frame: DataFrame
    class_column: str
        Column name containing class names
    ax: Matplotlib axis object, optional
    color: list or tuple, optional
        Colors to use for the different classes
    colormap : str or matplotlib colormap object, default None
        Colormap to select colors from. If string, load colormap with that name
        from matplotlib.
    kwds: keywords
        Options to pass to matplotlib scatter plotting method
    Returns:
    --------
    ax: Matplotlib axis object
    """
    import matplotlib.pyplot as plt
    import matplotlib.patches as patches

    def normalize(series):
        a = min(series)
        b = max(series)
        return (series - a) / (b - a)

    n = len(frame)
    classes = frame[class_column].drop_duplicates()
    class_col = frame[class_column]
    df = frame.drop(class_column, axis=1).apply(normalize)

    if ax is None:
        ax = plt.gca(xlim=[-1, 1], ylim=[-1, 1])

    to_plot = {}
    colors = _get_standard_colors(num_colors=len(classes), colormap=colormap,
                                  color_type='random', color=color)

    for kls in classes:
        to_plot[kls] = [[], []]

    m = len(frame.columns) - 1
    s = np.array([(np.cos(t), np.sin(t))
                  for t in [2.0 * np.pi * (i / float(m))
                            for i in range(m)]])

    for i in range(n):
        row = df.iloc[i].values
        row_ = np.repeat(np.expand_dims(row, axis=1), 2, axis=1)
        y = (s * row_).sum(axis=0) / row.sum()
        kls = class_col.iat[i]
        to_plot[kls][0].append(y[0])
        to_plot[kls][1].append(y[1])

    for i, kls in enumerate(classes):
        ax.scatter(to_plot[kls][0], to_plot[kls][1], color=colors[i],
                   label=com.pprint_thing(kls), **kwds)
    ax.legend()

    ax.add_patch(patches.Circle((0.0, 0.0), radius=1.0, facecolor='none'))

    for xy, name in zip(s, df.columns):

        ax.add_patch(patches.Circle(xy, radius=0.025, facecolor='gray'))

        if xy[0] < 0.0 and xy[1] < 0.0:
            ax.text(xy[0] - 0.025, xy[1] - 0.025, name,
                    ha='right', va='top', size='small')
        elif xy[0] < 0.0 and xy[1] >= 0.0:
            ax.text(xy[0] - 0.025, xy[1] + 0.025, name,
                    ha='right', va='bottom', size='small')
        elif xy[0] >= 0.0 and xy[1] < 0.0:
            ax.text(xy[0] + 0.025, xy[1] - 0.025, name,
                    ha='left', va='top', size='small')
        elif xy[0] >= 0.0 and xy[1] >= 0.0:
            ax.text(xy[0] + 0.025, xy[1] + 0.025, name,
                    ha='left', va='bottom', size='small')

    ax.axis('equal')
    return ax

# %%
scatter_matrix(df,figsize = (15,10));
#plt.savefig('scattermatrixnonorm.png')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x10affca90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10b0a3dd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10b231690>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10b2b2550>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x10b314350>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10b392590>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10b3d7bd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10b467e10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x10b4e8a50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10b5524d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10b5d3450>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10b7370d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x10b7b4310>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10b761050>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10b9938d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10ba14850>]], dtype=object)

# %% [markdown]
# from lightning import Lightning
# lgn = Lightning(host='https://radiant-peak-5255.herokuapp.com/', ipython=True)
# lgn.create_session('hello world')
# import networkx as nx
# from numpy import random
#
# G = nx.random_regular_graph(3,100)
# mat = nx.adjacency_matrix(G).todense()
# l = (random.rand(100)*5).astype('int')
#
# lgn.force(mat, label=l)
